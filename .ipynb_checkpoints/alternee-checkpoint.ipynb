# %%
# General import
import numpy as np
import os
from PIL import Image
from scipy import signal
from scipy import interpolate
import matplotlib.pyplot as plt
# %matplotlib inline
# Local import
from Codes.dataprocess import DataGen
from Codes.dataprocess import Export_ep
from Codes.alternate import AlternatingBD
from Codes.display import Display_ker
from Codes.display import Display_im
from Codes.display import Display_epd
from Codes.simplex import Simplex
from Codes.fbstep import Energy

# %% [markdown]
# # Minimisation alternée

# %% [markdown]
# Approche variationnelle pour la reconstruction d'un noyau régulier $K$, minimisation de l'énergie,
# $$
# E_1(K) = \frac{1}{2} \| g - K * u\|^2 + \frac{1}{2} \alpha \| D K \|^2
# \; .
# $$
# On peut considérer que le noyau appartien a l'ensemble des simplexe (ensemble des noyaux à coefficient positif dont la somme vaut 1).
# On sonsidere alors l'énergie
# $$
# E_1'(K) = \frac{1}{2} \| g - K * u\|^2 + \frac{1}{2} \alpha \| D K \|^2 + \Sigma(K)
# \; .
# $$
#
#
# Approche variationnelle pour la reconstruction de l'image $u$, avec régularisation TV,
# $$
# E_2(u) = \frac{1}{2} \| g - K * u\|^2 +  \mu \text{TV} (u)
# \; .
# $$
#
# Dans la minimisation alternée, on considere d'abord la minimisation de $E_2$
# pour reconstruire l'image $u$, puis de $E_1$ (ou éventuellement $E_1'$) pour reconstruire le noyau $K$.

# %%
K, K_shift, x_i, x_b, x_o1 = DataGen()
# Out:
# Erreur |Shift - True|/ |True| : 0.4667
# Erreur blurred |x_blurr- x_true|_2 :0.5683
# Erreur |x_noisy - x_true|_2 :0.5734

# %% [markdown]
# ## Initialisation noyau proche - pas de bruit

# %%
alpha = 10
mu    = 0.005
K_in  = K_shift.copy()
x_in  = x_o1
K_out,x_out,Ep12,Ed12 = AlternatingBD(K_in,x_in,x_o1,alpha,mu,\
                  alte=4,niter_TV=1500,niter_Lap=500,\
                  proj_simplex=True)
# Out:
# ------------- min image -----------------
# iteration 0 %--- gradient K 715.0191 --- gradient x 2.2168
# iteration 500 %--- gradient K 51.7382 --- gradient x 0.1465
# iteration 1000 %--- gradient K 51.1785 --- gradient x 0.1442
# iteration 1500 %--- gradient K 51.1327 --- gradient x 0.1436
# iteration 2000 %--- gradient K 51.1353 --- gradient x 0.1433
# iteration 2500 %--- gradient K 51.1515 --- gradient x 0.1432
# Energie =  5.719640706024455
# ------------- min kernel -----------------
# iteration 3000 %--- gradient K 70.8869 --- gradient x 0.1441
# iteration 3500 %--- gradient K 63.3687 --- gradient x 0.1658
# iteration 4000 %--- gradient K 66.7498 --- gradient x 0.1671
# Energie =  5.709698309788062
# ------------- min image -----------------
# iteration 4500 %--- gradient K 61.2376 --- gradient x 0.1613
# iteration 5000 %--- gradient K 53.9028 --- gradient x 0.1444
# iteration 5500 %--- gradient K 53.8521 --- gradient x 0.1444
# iteration 6000 %--- gradient K 53.8472 --- gradient x 0.1444
# iteration 6500 %--- gradient K 53.8510 --- gradient x 0.1444
# iteration 7000 %--- gradient K 53.8572 --- gradient x 0.1444
# Energie =  5.695738091835347
# ------------- min kernel -----------------
# iteration 7500 %--- gradient K 73.8624 --- gradient x 0.1454
# iteration 8000 %--- gradient K 61.2677 --- gradient x 0.1651
# iteration 8500 %--- gradient K 63.6623 --- gradient x 0.1661
# Energie =  5.688544508095697
# ------------- min image -----------------
# iteration 9000 %--- gradient K 59.5061 --- gradient x 0.1600
# iteration 9500 %--- gradient K 55.2303 --- gradient x 0.1456
# iteration 10000 %--- gradient K 55.2036 --- gradient x 0.1456
# iteration 10500 %--- gradient K 55.2033 --- gradient x 0.1456
# iteration 11000 %--- gradient K 55.2044 --- gradient x 0.1457
# iteration 11500 %--- gradient K 55.2052 --- gradient x 0.1457
# Energie =  5.678354493898279
# ------------- min kernel -----------------
# iteration 12000 %--- gradient K 75.2912 --- gradient x 0.1466
# iteration 12500 %--- gradient K 60.8156 --- gradient x 0.1648
# iteration 13000 %--- gradient K 62.6572 --- gradient x 0.1657
# Energie =  5.671966904058104
# ------------- min image -----------------
# iteration 13500 %--- gradient K 58.7874 --- gradient x 0.1594
# iteration 14000 %--- gradient K 55.6275 --- gradient x 0.1464
# iteration 14500 %--- gradient K 55.6059 --- gradient x 0.1464
# iteration 15000 %--- gradient K 55.6064 --- gradient x 0.1465
# iteration 15500 %--- gradient K 55.6084 --- gradient x 0.1465
# iteration 16000 %--- gradient K 55.6098 --- gradient x 0.1465
# Energie =  5.663165685841051
# ------------- min kernel -----------------
# iteration 16500 %--- gradient K 75.7902 --- gradient x 0.1474
# iteration 17000 %--- gradient K 60.9067 --- gradient x 0.1644
# iteration 17500 %--- gradient K 62.1050 --- gradient x 0.1655
# Energie =  5.657267217702137
# Final energy : 5.657267217702137

# %%
# Display_ker(K_out,K_in,mysize=(8,4))
Display_ker(K_out,K,mysize=(8,4))
Display_im(x_out,x_i,mysize=(6,3))
Display_epd(Ep12,Ed12)
# Out:
# Erreur |K1 - K2|/ |K2| : 0.5842
# Erreur |im1 - im2|/|im2| :0.5516

# %%
plt.plot(K_shift[20,:],label='shift')
plt.plot(K_out[20,:],label='out')
plt.plot(K[20,:],label='true')
plt.legend()

# %% [markdown]
# ## Initialisation proche - bruit 1%

# %%
alpha = 10
mu    = 0.005
K_in  = K_shift.copy()
x_in  = x_o1
K_out,x_out,Ep13,Ed13 = AlternatingBD(K_in,x_in,x_o1,alpha,mu,\
                  alte=4,niter_TV=1500,niter_Lap=1500,\
                  proj_simplex=True)
# Out:
# ------------- min image -----------------
# iteration 0 %--- gradient K 715.0191 --- gradient x 2.2168
# iteration 500 %--- gradient K 51.7382 --- gradient x 0.1465
# iteration 1000 %--- gradient K 51.1785 --- gradient x 0.1442
# iteration 1500 %--- gradient K 51.1327 --- gradient x 0.1436

# %%
Display_ker(K_out,K,mysize=(8,4))
Display_im(x_out,x_i,mysize=(6,3))
Display_epd(Ep13,Ed13)

# %%
from Codes.simplex import Simplex
plt.plot(K_shift[20,:],label='shift')
plt.plot(K_out[20,:],label='out')
plt.plot(K[20,:],label='true')
plt.legend()
