# %%
import numpy as np
import matplotlib.pyplot as plt
# Local import
from dataprocess import DataLoader, Blurr

# %%
import os
from PIL import Image
from scipy import signal

# %% [markdown]
# ## Pre-process images

# %% [markdown]
# ### Load image

# %%
file_name = 'Images'
im_name   = 'image01.png'
x_init = DataLoader(file_name,im_name)
plt.imshow(x_init)

# %% [markdown]
# ### Define gaussian kernel

# %%
M=10
Nx, Ny = np.meshgrid(np.linspace(-1,1,2*M), np.linspace(-1,1,2*M))
d = np.sqrt(Nx*Nx+Ny*Ny)
sigma, mu = 0.5, 0.0
K = np.exp(-( (d-mu)**2 / ( 2.0 * sigma**2 ) ) )
K = K/K.sum()
print("2D Gaussian-like array:")
plt.imshow(K)
# Out:
# 2D Gaussian-like array:

# %%
K.ndim
# Out:
# 2

# %%
K_padd = np.pad(K, ((300-M,300-M),(400-M,400-M)), 'constant')
K_padd.shape
# Out:
# (600, 800)

# %%
plt.imshow(K_padd)

# %% [markdown]
# ### Blurr and add noise

# %%
x_b = Blurr(x_init,K_padd)
# Out:
# <class 'numpy.ndarray'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-f95f0582707d> in <module>
# ----> 1 x_b = Blurr(x_init,K_padd)
#
# ~/Documents/BlindDeconvolution/dataprocess.py in Blurr(x_init, K)
#      51         x_blurred (numpy array): output image
#      52     """
# ---> 53     x_blurred = fft_convolve2d(K,x_init)
#      54     return x_blurred
#      55
#
# ~/Documents/BlindDeconvolution/dataprocess.py in fft_convolve2d(x, y)
#      61     cc = np.real(ifft2(fr*fr2))
#      62     cc = np.roll(cc, -m/2+1,axis=0)
# ---> 63     cc = np.roll(cc, -n/2+1,axis=1)
#      64     return cc
#
# <__array_function__ internals> in roll(*args, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/numpy/core/numeric.py in roll(a, shift, axis)
#    1207         for indices in itertools.product(*rolls):
#    1208             arr_index, res_index = zip(*indices)
# -> 1209             result[res_index] = a[arr_index]
#    1210
#    1211         return result
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
m=30
# Out:
# 15.0
