# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Local import
from dataprocess import DataLoader, Blurr, Add_noise
from estimator import Estimator
from posttreat import Display

# %%
import os
from PIL import Image
from scipy import signal
from scipy import interpolate

# %% [markdown]
# ## Pre-process images

# %% [markdown]
# ### Load image

# %%
file_name = 'Images'
im_name   = 'image01.png'
x_i = DataLoader(file_name,im_name)
# Taille de l'image
print("Taille de l'image :")
x_i.shape
# Out:
# Taille de l'image :
# (600, 800)

# %% [markdown]
# ### Define gaussian kernel

# %%
M=20
Nx, Ny = np.meshgrid(np.linspace(-1,1,2*M), np.linspace(-1,1,2*M))
d = np.sqrt(Nx*Nx+Ny*Ny)
sigma, mu = 0.5, 0.0
K = np.exp(-( (d-mu)**2 / ( 2.0 * sigma**2 ) ) )
K = K/K.sum()
print("2D Gaussian-like array:")
plt.imshow(K)
# Out:
# 2D Gaussian-like array:

# %%
# Interpolate the Kernel diagonal
f        = interpolate.interp1d(np.diag(Nx), np.diag(K))
Nxnew    = np.linspace(-1,1, 100)
K_interp = f(Nxnew)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2 , figsize=(15,7))
ax1.plot(np.diag(Nx), np.diag(K), '-+')
ax1.axis(ymin=0)
ax2.plot(Nxnew, K_interp, 'r+')
ax2.axis(ymin=0)
# Out:
# (-1.1, 1.1, 0.0, 0.00029771100158979767)

# %% [markdown]
# ### Blurr and add noise

# %%
x_b = Blurr(x_i,K)
x_o1 = Add_noise(x_b)
x_o2 = Add_noise(x_b, noise_level = 0.1)

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2 , figsize=(15,15))
ax1.imshow(x_i)
ax1.set_title('Init')
ax1.axis('off')
ax2.imshow(x_b)
ax2.set_title('Blurred')
ax2.axis('off')
ax3.imshow(x_o1)
ax3.set_title('Noise = 5%')
ax3.axis('off')
ax4.imshow(x_o2)
ax4.set_title('Noise = 10%')
ax4.axis('off')
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %% [markdown]
# ## Solve inverse problem - No Noise

# %%
from estimator import Estimator
alpha = 1
mu = 1
K_alpha = Estimator(M,x_i,x_b,alpha,mu,niter = 500)

# %%
K_alpha.shape
# Out:
# (100, 100)

# %%
fig, (ax1, ax2,ax3) = plt.subplots(1, 3 ,figsize=(12,12))
ax1.imshow(K)
ax1.set_title('Real')
ax1.axis('off')
ax2.imshow(K_alpha)
ax2.set_title('Reconstruct')
ax2.axis('off')
ax3.imshow(K_alpha-K)
ax3.set_title('Difference')
ax3.axis('off')
# Out:
# (-0.5, 99.5, 99.5, -0.5)

# %%
Display(K,K_alpha)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-d42175f6b50a> in <module>
# ----> 1 Display(K,K_alpha)
#
# ~/Documents/BlindDeconvolution/posttreat.py in Display(K_init, K_alpha, Ninterp)
#      30     """
#      31     # Interpolate the Kernel diagonal
# ---> 32     Nx     = np.linspace(-1,1,K_init.shape[0])
#      33     fi     = interpolate.interp1d(Nx, np.diag(K_init))
#      34     fa     = interpolate.interp1d(Nx, np.diag(K_alpha))
#
# NameError: name 'interpolate' is not defined

# %% [markdown]
# ## Solve inverse problem - With noise

# %%
alpha = 2
mu = 1
K_a1 = Estimator(M,x_i,x_o1,alpha,mu,niter = 500)

# %%
alpha = 100
mu = 1
K_a2 = Estimator(M,x_i,x_o1,alpha,mu,niter = 500)

# %%
fig, (ax1, ax2,ax3) = plt.subplots(1, 3 ,figsize=(12,12))
ax1.imshow(K)
ax1.set_title('Real')
ax1.axis('off')
ax2.imshow(K_a1)
ax2.set_title('Reconstruct noise = 10%')
ax2.axis('off')
ax3.imshow(K_a2)
ax3.set_title('Reconstruct noise = 5%')
ax3.axis('off')
# Out:
# (-0.5, 19.5, 19.5, -0.5)
