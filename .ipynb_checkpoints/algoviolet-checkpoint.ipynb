# %%
# General import
import numpy as np
from numpy.fft import fft2, ifft2, fftshift
import matplotlib.pyplot as plt
# %matplotlib inline
# Local import
from Codes.dataprocess import DataGen
from Codes.dataprocess import Export_ep
from Codes.algoviolet import violetBD
from Codes.display import Display_ker
from Codes.display import Display_im
from Codes.display import Display_epd
from Codes.myfunc import nablah
from Codes.myfunc import convolve
from Codes.simplex import Simplex

# %% [markdown]
# # Minimisation fonction bi-convexe concave

# %% [markdown]
# On introduit le probleme d'optimisation biconvex-concave
# de déconvolution aveugle d'images
# avec l' a priori de noyau de convolution régulier,
#
# $$
# \underset{u \in U ,K \in \Sigma}{\text{min}} \; \underset{v}{\text{sup}} \;
# \frac{1}{2} \gamma \| g - K * u\|^2
# + \frac{1}{2} \alpha \| D K \|^2
# + \langle \nabla u , v \rangle
# + \chi_{B,\mu}(v)
# \; .
# $$
#
# L'espace $\Sigma$ correspond à l'ensemble des simplexes
# (ensemble des noyaux à coefficient positif dont la somme des coefficients vaut 1).
# Par extension on notera $\Sigma$ la fonction indicatrice de cet ensemble.
# L'espace $U$ correspond à l'hypercube $[0,1]^{N_x \times N_y}$, ou la boule unité pour la norme $L^\infty$.
# Sa fonction indicatrice correspond donc à $\chi_{B,1}$.
#
# La fonction à minimiser peut alors se réécrire
#
# $$
# \underset{u ,K }{\text{min}} \; \underset{v}{\text{sup}} \;
# \frac{1}{2}\gamma \| g - K * u\|^2
# + \chi_{B,1} (u)
# + \frac{1}{2} \alpha \| D K \|^2
# + \Sigma(K)
# +\langle \nabla u , v \rangle
# + \chi_{B,\mu}(v)
# \; .
# $$

# %% [markdown]
# On note
#
# $$
# L =\frac{1}{2} \gamma \| g - K * u\|^2
# + \frac{1}{2} \alpha \| D K \|^2
# + \langle \nabla u , v \rangle
# $$

# %% [markdown]
# Pour résoudre ce probleme d'optimisation on se propose de tester l'algorithme suivant,
#
# $$
# \left\{
# \begin{align}
# & K_{k+1} = \text{prox}_{\Sigma} \; (K_k - \gamma \partial_K L(\tilde{u}_{k+1},K_k,v_k) \; )\\
# & \tilde{u}_{k+1} = \text{proj}_{B_1} \; (u_k - \tau \partial_u L(u_k,K_k,v_k) \; )\\
# & v_{k+1}         = \text{prox}_{B_\mu} \; (v_k + \sigma \partial_v L (u_{k+1},K_{k+1},v_k) \; )\\
# & u_{k+1} = \tilde{u}_{k+1} + \theta_u (\tilde{u}_{k+1} - u_k) \quad \text{(relaxation)}
# \end{align}
# \right.
# $$
#
# Question :
# est-ce qu'on met une relaxation aussi sur $K$ ?
#
# $$
# K_{k+1} = \tilde{K}_{k+1} + \theta_K (\tilde{K}_{k+1} - K_k)  \quad \text{(relaxation aussi ?)}
# $$
#
# On écrit alors les dérivées partielles de $L$,
#
# $$
# \left\{
# \begin{align}
# & \partial_u L(u_k,K_k,v_k) \; ) = \text{div} \cdot v_k - \tilde{K} * (g-K*u)\\
# & \partial_K L(\tilde{u}_{k+1},K_k,v_k) \; ) = - (g-K*u)*\tilde{u} + \alpha D^TDK \\
# & \partial_v L (u_{k+1},K_{k+1},v_k) \; ) =  \nabla u
# \end{align}
# \right.
# $$
#
# On trace les énergies primales et duales au cours de la minimisation
#
# $$
# \left\{
# \begin{align}
# & Ep = \frac{1}{2} \| g - K * u\|^2
# + \frac{1}{2} \alpha \| D K \|^2
# + \mu. \text{TV} (u) \\
# \\
# & Ed = - \langle \nabla u ,v \rangle - \chi_{B,\mu}(v)
# \end{align}
# \right.
# $$

# %%
K1, K2, x_im, x_b, x_o1 = DataGen()
# Out:
# Erreur |Shift - True|/ |True| : 0.4667
# Erreur blurred |x_blurr- x_true|_2 :0.5786
# Erreur |x_noisy - x_true|_2 :0.5796

# %% [markdown]
# ## Initialisation noyau exact - pas de bruit

# %%
alpha     = 0.0
mu        = 0.001
K_in      = K1.copy()
x_in      = x_im.copy()
K_out,x_out,Ep22,Ed22 = violetBD(x_in,K_in,x_b,alpha,mu,\
                            niter=10000,coeffK=0.0,coeffx=1,\
                            proj_simplex=True)
# Out:
# iteration 200 %--- gradient K 14.0067 --- gradient x 0.0333
# iteration 400 %--- gradient K 25.6809 --- gradient x 0.0343
# iteration 600 %--- gradient K 36.5395 --- gradient x 0.0376
# iteration 800 %--- gradient K 46.0903 --- gradient x 0.0420
# iteration 1000 %--- gradient K 54.6557 --- gradient x 0.0464
# iteration 1200 %--- gradient K 62.4652 --- gradient x 0.0509
# iteration 1400 %--- gradient K 69.9896 --- gradient x 0.0555
# iteration 1600 %--- gradient K 76.8539 --- gradient x 0.0597
# iteration 1800 %--- gradient K 83.2869 --- gradient x 0.0638
# iteration 2000 %--- gradient K 89.1910 --- gradient x 0.0676
# iteration 2200 %--- gradient K 94.7500 --- gradient x 0.0712
# iteration 2400 %--- gradient K 100.0235 --- gradient x 0.0747
# iteration 2600 %--- gradient K 105.0097 --- gradient x 0.0780
# iteration 2800 %--- gradient K 109.7036 --- gradient x 0.0812
# iteration 3000 %--- gradient K 114.1971 --- gradient x 0.0843
# iteration 3200 %--- gradient K 118.4655 --- gradient x 0.0872
# iteration 3400 %--- gradient K 122.6857 --- gradient x 0.0901
# iteration 3600 %--- gradient K 126.8832 --- gradient x 0.0929
# iteration 3800 %--- gradient K 130.7667 --- gradient x 0.0956
# iteration 4000 %--- gradient K 134.4347 --- gradient x 0.0982
# iteration 4200 %--- gradient K 137.7923 --- gradient x 0.1005
# iteration 4400 %--- gradient K 140.9624 --- gradient x 0.1028
# iteration 4600 %--- gradient K 143.9451 --- gradient x 0.1048
# iteration 4800 %--- gradient K 146.6866 --- gradient x 0.1068
# iteration 5000 %--- gradient K 149.2335 --- gradient x 0.1086
# iteration 5200 %--- gradient K 151.5908 --- gradient x 0.1102
# iteration 5400 %--- gradient K 153.7932 --- gradient x 0.1118
# iteration 5600 %--- gradient K 155.8818 --- gradient x 0.1133
# iteration 5800 %--- gradient K 157.8749 --- gradient x 0.1147
# iteration 6000 %--- gradient K 159.7634 --- gradient x 0.1161
# iteration 6200 %--- gradient K 161.4905 --- gradient x 0.1173
# iteration 6400 %--- gradient K 163.1323 --- gradient x 0.1185
# iteration 6600 %--- gradient K 164.6234 --- gradient x 0.1196
# iteration 6800 %--- gradient K 165.9603 --- gradient x 0.1206
# iteration 7000 %--- gradient K 167.1718 --- gradient x 0.1215
# iteration 7200 %--- gradient K 168.3053 --- gradient x 0.1223
# iteration 7400 %--- gradient K 169.3786 --- gradient x 0.1231
# iteration 7600 %--- gradient K 170.4248 --- gradient x 0.1239
# iteration 7800 %--- gradient K 171.4013 --- gradient x 0.1247
# iteration 8000 %--- gradient K 172.3121 --- gradient x 0.1254
# iteration 8200 %--- gradient K 173.1634 --- gradient x 0.1261
# iteration 8400 %--- gradient K 173.9629 --- gradient x 0.1267
# iteration 8600 %--- gradient K 174.7067 --- gradient x 0.1273
# iteration 8800 %--- gradient K 175.4174 --- gradient x 0.1279
# iteration 9000 %--- gradient K 176.1104 --- gradient x 0.1284
# iteration 9200 %--- gradient K 176.7645 --- gradient x 0.1289
# iteration 9400 %--- gradient K 177.3787 --- gradient x 0.1294
# iteration 9600 %--- gradient K 177.9591 --- gradient x 0.1299
# iteration 9800 %--- gradient K 178.5138 --- gradient x 0.1303
# Final energy : 0.6618107237891002

# %%
Display_ker(K_out,K_in,mysize=(8,4))
Display_im(x_out,x_im,mysize=(6,3))
Display_epd(Ep22,Ed22)
# Out:
# Erreur |K1 - K2|/ |K2| : 0.0000
# Erreur |im1 - im2|/|im2| :0.3887

# %% [markdown]
# ## Initialisation du noyau exacte - bruit std 0.05
#
# Les erreurs initiales sont
#
# $$
# \begin{cases}
# e_K = 0 \\
# e_x = 0.2577
# \end{cases}
# $$

# %%
alpha = 0.001
mu    = 0.005
K_in   = K1.copy()
x_in  = x_o1
K_out,x_out,Ep21,Ed21 = violetBD(x_in,K_in,x_b,alpha,mu,\
                            niter=3000,coeffK=0.001,coeffx=0.1,\
                            proj_simplex=True)
# (1/tau_u - Lf) = sqrt(8)
# tau_v = coeff_v1/sqrt(8)
# tau_k = coeff_K*2/L_total
# (1/tau_u - Lf)1/tau_v <8
# Out:
# iteration 60 %--- gradient K 1198.9296 --- gradient x 2.0879
# iteration 120 %--- gradient K 1377.5571 --- gradient x 1.6450
# iteration 180 %--- gradient K 1380.4474 --- gradient x 1.4189
# iteration 240 %--- gradient K 1321.8170 --- gradient x 1.2686
# iteration 300 %--- gradient K 1247.0083 --- gradient x 1.1569
# iteration 360 %--- gradient K 1169.2147 --- gradient x 1.0705
# iteration 420 %--- gradient K 1099.0220 --- gradient x 1.0023
# iteration 480 %--- gradient K 1035.4580 --- gradient x 0.9436
# iteration 540 %--- gradient K 978.8020 --- gradient x 0.8929
# iteration 600 %--- gradient K 929.9492 --- gradient x 0.8504
# iteration 660 %--- gradient K 888.0578 --- gradient x 0.8140
# iteration 720 %--- gradient K 849.3488 --- gradient x 0.7807
# iteration 780 %--- gradient K 814.3380 --- gradient x 0.7505
# iteration 840 %--- gradient K 783.3732 --- gradient x 0.7238
# iteration 900 %--- gradient K 755.1203 --- gradient x 0.6991
# iteration 960 %--- gradient K 729.0799 --- gradient x 0.6762
# iteration 1020 %--- gradient K 706.1763 --- gradient x 0.6557
# iteration 1080 %--- gradient K 685.2405 --- gradient x 0.6369
# iteration 1140 %--- gradient K 666.2018 --- gradient x 0.6195
# iteration 1200 %--- gradient K 648.3756 --- gradient x 0.6036
# iteration 1260 %--- gradient K 631.9986 --- gradient x 0.5890
# iteration 1320 %--- gradient K 616.6233 --- gradient x 0.5751
# iteration 1380 %--- gradient K 602.0142 --- gradient x 0.5619
# iteration 1440 %--- gradient K 588.2688 --- gradient x 0.5496
# iteration 1500 %--- gradient K 575.1214 --- gradient x 0.5378
# iteration 1560 %--- gradient K 562.8487 --- gradient x 0.5269
# iteration 1620 %--- gradient K 550.9805 --- gradient x 0.5165
# iteration 1680 %--- gradient K 539.5940 --- gradient x 0.5066
# iteration 1740 %--- gradient K 528.6891 --- gradient x 0.4971
# iteration 1800 %--- gradient K 518.1756 --- gradient x 0.4879
# iteration 1860 %--- gradient K 508.0686 --- gradient x 0.4793
# iteration 1920 %--- gradient K 498.3904 --- gradient x 0.4709
# iteration 1980 %--- gradient K 488.9170 --- gradient x 0.4627
# iteration 2040 %--- gradient K 479.8654 --- gradient x 0.4550
# iteration 2100 %--- gradient K 471.2354 --- gradient x 0.4476
# iteration 2160 %--- gradient K 462.9988 --- gradient x 0.4405
# iteration 2220 %--- gradient K 454.9170 --- gradient x 0.4336
# iteration 2280 %--- gradient K 447.0210 --- gradient x 0.4270
# iteration 2340 %--- gradient K 439.4943 --- gradient x 0.4207
# iteration 2400 %--- gradient K 432.5268 --- gradient x 0.4148
# iteration 2460 %--- gradient K 425.8204 --- gradient x 0.4092
# iteration 2520 %--- gradient K 419.2788 --- gradient x 0.4036
# iteration 2580 %--- gradient K 412.9659 --- gradient x 0.3982
# iteration 2640 %--- gradient K 406.7940 --- gradient x 0.3930
# iteration 2700 %--- gradient K 400.6973 --- gradient x 0.3878
# iteration 2760 %--- gradient K 394.7716 --- gradient x 0.3828
# iteration 2820 %--- gradient K 389.0430 --- gradient x 0.3779
# iteration 2880 %--- gradient K 383.6008 --- gradient x 0.3731
# iteration 2940 %--- gradient K 378.2792 --- gradient x 0.3685
# Final energy : 2.848063640072147

# %%
Display_ker(K_out,K1,mysize=(8,4),label1='out',label2='true')
Display_im(x_out,x_im,mysize=(6,3))
Display_epd(Ep21,Ed21)
# Out:
# Erreur |out - true|/ |true| : 0.0541
# Erreur |im1 - im2|/|im2| :0.4902

# %%
# Export_ep(Ep21,label='2',cas='1')

# %% [markdown]
# ## Initialisation noyau proche - bruit std 0.05
# Les erreurs initiales sont
#
# $$
# \begin{cases}
# e_K=0.2811 \\
# e_x=0.2724
# \end{cases}
# $$

# %%
alpha     = 0.1
mu        = 0.01
K_in      = K2.copy()
x_in      = np.zeros(x_im.shape)
K_out,x_out,Ep23,Ed23 = violetBD(x_in,K_in,x_o1,\
                            alpha,mu,coeffK=0.1,coeffx=0.1,\
                            niter=500,\
                            proj_simplex=True)
# Out:
# iteration 10 %--- gradient K 8752.8286 --- gradient x 23.1395
# iteration 20 %--- gradient K 13054.0668 --- gradient x 20.9679
# iteration 30 %--- gradient K 15052.8514 --- gradient x 19.5373
# iteration 40 %--- gradient K 15499.1111 --- gradient x 18.6975
# iteration 50 %--- gradient K 14948.7598 --- gradient x 18.4211
# iteration 60 %--- gradient K 13857.9578 --- gradient x 18.6130
# iteration 70 %--- gradient K 12667.6344 --- gradient x 19.2088
# iteration 80 %--- gradient K 11872.7635 --- gradient x 20.1812
# iteration 90 %--- gradient K 11979.4795 --- gradient x 21.4484
# iteration 100 %--- gradient K 13304.3176 --- gradient x 22.9694
# iteration 110 %--- gradient K 15853.3708 --- gradient x 24.7186
# iteration 120 %--- gradient K 19449.1725 --- gradient x 26.5475
# iteration 130 %--- gradient K 24001.0702 --- gradient x 28.4455
# iteration 140 %--- gradient K 29423.2241 --- gradient x 30.4196
# iteration 150 %--- gradient K 35617.5400 --- gradient x 32.4293
# iteration 160 %--- gradient K 42527.8032 --- gradient x 34.4914
# iteration 170 %--- gradient K 50068.0589 --- gradient x 36.5165
# iteration 180 %--- gradient K 57892.5101 --- gradient x 38.1076
# iteration 190 %--- gradient K 65690.4946 --- gradient x 39.1267
# iteration 200 %--- gradient K 73209.1079 --- gradient x 39.5798
# iteration 210 %--- gradient K 80249.3987 --- gradient x 39.5662
# iteration 220 %--- gradient K 86431.3571 --- gradient x 39.0912
# iteration 230 %--- gradient K 91704.9589 --- gradient x 38.3578
# iteration 240 %--- gradient K 95925.2009 --- gradient x 37.4422
# iteration 250 %--- gradient K 99284.2728 --- gradient x 36.5211
# iteration 260 %--- gradient K 102244.6495 --- gradient x 35.8320
# stops at 261 iterations : gradient of K rises

# %%
#Export_ep(Ep23,label='2',cas='3')

# %%
Display_ker(K_out,K1,mysize=(12,4),label1='out',label2='true')
Display_ker(K_out,K2,mysize=(12,4),label1='out',label2='shift')
Display_im(x_out,x_im,mysize=(6,3))
Display_epd(Ep23,Ed23)
# Out:
# Erreur |out - true|/ |true| : 1.5953
# Erreur |out - shift|/ |shift| : 1.3711
# Erreur |im1 - im2|/|im2| :1.5006
