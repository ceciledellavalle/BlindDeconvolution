# %%
# General import
import numpy as np
from numpy.fft import fft2, ifft2, fftshift
import matplotlib.pyplot as plt
# %matplotlib inline
# Local import
from Codes.dataprocess import DataGen
from Codes.dataprocess import Export_ep
from Codes.algoviolet import violetBD
from Codes.display import Display_ker
from Codes.display import Display_im
from Codes.display import Display_epd
from Codes.myfunc import nablah
from Codes.myfunc import convolve
from Codes.simplex import Simplex

# %% [markdown]
# # Minimisation fonction bi-convexe concave

# %% [markdown]
# On introduit le probleme d'optimisation biconvex-concave
# de déconvolution aveugle d'images
# avec l' a priori de noyau de convolution régulier,
#
# $$
# \underset{u \in U ,K \in \Sigma}{\text{min}} \; \underset{v}{\text{sup}} \;
# \frac{1}{2} \gamma \| g - K * u\|^2
# + \frac{1}{2} \alpha \| D K \|^2
# + \langle \nabla u , v \rangle
# + \chi_{B,\mu}(v)
# \; .
# $$
#
# L'espace $\Sigma$ correspond à l'ensemble des simplexes
# (ensemble des noyaux à coefficient positif dont la somme des coefficients vaut 1).
# Par extension on notera $\Sigma$ la fonction indicatrice de cet ensemble.
# L'espace $U$ correspond à l'hypercube $[0,1]^{N_x \times N_y}$, ou la boule unité pour la norme $L^\infty$.
# Sa fonction indicatrice correspond donc à $\chi_{B,1}$.
#
# La fonction à minimiser peut alors se réécrire
#
# $$
# \underset{u ,K }{\text{min}} \; \underset{v}{\text{sup}} \;
# \frac{1}{2}\gamma \| g - K * u\|^2
# + \chi_{B,1} (u)
# + \frac{1}{2} \alpha \| D K \|^2
# + \Sigma(K)
# +\langle \nabla u , v \rangle
# + \chi_{B,\mu}(v)
# \; .
# $$

# %% [markdown]
# On note
#
# $$
# L =\frac{1}{2} \gamma \| g - K * u\|^2
# + \frac{1}{2} \alpha \| D K \|^2
# + \langle \nabla u , v \rangle
# $$

# %% [markdown]
# Pour résoudre ce probleme d'optimisation on se propose de tester l'algorithme suivant,
#
# $$
# \left\{
# \begin{align}
# & K_{k+1} = \text{prox}_{\Sigma} \; (K_k - \gamma \partial_K L(\tilde{u}_{k+1},K_k,v_k) \; )\\
# & \tilde{u}_{k+1} = \text{proj}_{B_1} \; (u_k - \tau \partial_u L(u_k,K_k,v_k) \; )\\
# & v_{k+1}         = \text{prox}_{B_\mu} \; (v_k + \sigma \partial_v L (u_{k+1},K_{k+1},v_k) \; )\\
# & u_{k+1} = \tilde{u}_{k+1} + \theta_u (\tilde{u}_{k+1} - u_k) \quad \text{(relaxation)}
# \end{align}
# \right.
# $$
#
# Question :
# est-ce qu'on met une relaxation aussi sur $K$ ?
#
# $$
# K_{k+1} = \tilde{K}_{k+1} + \theta_K (\tilde{K}_{k+1} - K_k)  \quad \text{(relaxation aussi ?)}
# $$
#
# On écrit alors les dérivées partielles de $L$,
#
# $$
# \left\{
# \begin{align}
# & \partial_u L(u_k,K_k,v_k) \; ) = \text{div} \cdot v_k - \tilde{K} * (g-K*u)\\
# & \partial_K L(\tilde{u}_{k+1},K_k,v_k) \; ) = - (g-K*u)*\tilde{u} + \alpha D^TDK \\
# & \partial_v L (u_{k+1},K_{k+1},v_k) \; ) =  \nabla u
# \end{align}
# \right.
# $$
#
# On trace les énergies primales et duales au cours de la minimisation
#
# $$
# \left\{
# \begin{align}
# & Ep = \frac{1}{2} \| g - K * u\|^2
# + \frac{1}{2} \alpha \| D K \|^2
# + \mu. \text{TV} (u) \\
# \\
# & Ed = - \langle \nabla u ,v \rangle - \chi_{B,\mu}(v)
# \end{align}
# \right.
# $$

# %%
K, K_shift, x_im, x_b, x_o1 = DataGen()
# Out:
# Erreur |K1 - K2|/ |K2| : 0.3500
# Erreur blurred |x_blurr- x_true|_2 :0.5093
# Erreur |x_noisy - x_true|_2 :0.5109

# %% [markdown]
# ## Initialisation du noyau exacte - bruit std 0.05
#
# Les erreurs initiales sont
#
# $$
# \begin{cases}
# e_K = 0 \\
# e_x = 0.2577
# \end{cases}
# $$

# %%
# alpha = 100
# mu    = 0.001
# K_in   = K.copy()
# x_in  = x_o1
# K_out,x_out,Ep21,Ed21 = violetBD(K_in,x_in,x_b,alpha,mu,\
#                             niter=10000,coeffK=0.01,\
#                             proj_simplex=True)

# %%
# Display_ker(K_out,K_in,mysize=(8,4))
# Display_im(x_out,x_im,mysize=(6,3))
# Display_epd(Ep21,Ed21)

# %%
# from Codes.simplex import Simplex
# plt.plot(K_shift[20,:],label='shift')
# plt.plot(K_out[20,:],label='out')
# plt.plot(K[20,:],label='true')
# plt.legend()

# %%
# Export_ep(Ep21,label='2',cas='1')

# %% [markdown]
# ## Initialisation noyau proche - pas de bruit

# %%
alpha     = 1
mu        = 0.1
K_in      = K.copy()
x_in      = x_b
K_out,x_out,Ep22,Ed22 = violetBD(K_in,x_in,x_b,alpha,mu,\
                            niter=3000,coeffK=1,\
                            proj_simplex=True)
# Out:
# iteration 60 %--- gradient K 1032.9424 --- gradient x 1.6207
# iteration 120 %--- gradient K 655.8557 --- gradient x 1.3930
# iteration 180 %--- gradient K 513.3336 --- gradient x 1.4761
# iteration 240 %--- gradient K 449.9715 --- gradient x 1.5817
# iteration 300 %--- gradient K 432.7127 --- gradient x 1.7996
# iteration 360 %--- gradient K 417.8630 --- gradient x 2.0689
# iteration 420 %--- gradient K 407.1579 --- gradient x 2.3326
# iteration 480 %--- gradient K 403.6343 --- gradient x 2.8723
# iteration 540 %--- gradient K 403.1145 --- gradient x 3.5421
# iteration 600 %--- gradient K 403.0855 --- gradient x 4.3529
# iteration 660 %--- gradient K 403.1280 --- gradient x 5.4413
# iteration 720 %--- gradient K 402.8709 --- gradient x 6.7692
# iteration 780 %--- gradient K 402.0987 --- gradient x 8.2685
# iteration 840 %--- gradient K 399.5962 --- gradient x 9.8013
# iteration 900 %--- gradient K 396.6655 --- gradient x 11.2022
# iteration 960 %--- gradient K 393.8219 --- gradient x 12.4574
# iteration 1020 %--- gradient K 391.1811 --- gradient x 13.3863
# iteration 1080 %--- gradient K 388.3316 --- gradient x 13.9923
# iteration 1140 %--- gradient K 386.0810 --- gradient x 14.4413
# iteration 1200 %--- gradient K 384.2360 --- gradient x 14.8177
# iteration 1260 %--- gradient K 382.8097 --- gradient x 15.2671
# iteration 1320 %--- gradient K 382.0000 --- gradient x 15.6066
# iteration 1380 %--- gradient K 381.6425 --- gradient x 15.7489
# iteration 1440 %--- gradient K 381.6498 --- gradient x 15.8431
# iteration 1500 %--- gradient K 381.8935 --- gradient x 15.9490
# iteration 1560 %--- gradient K 382.2525 --- gradient x 16.0128
# iteration 1620 %--- gradient K 382.6182 --- gradient x 16.0848
# iteration 1680 %--- gradient K 383.0206 --- gradient x 16.2219
# iteration 1740 %--- gradient K 383.4428 --- gradient x 16.2991
# iteration 1800 %--- gradient K 383.8666 --- gradient x 16.3521
# iteration 1860 %--- gradient K 384.5207 --- gradient x 16.4660
# iteration 1920 %--- gradient K 385.0159 --- gradient x 16.6121
# iteration 1980 %--- gradient K 385.4902 --- gradient x 16.7037
# iteration 2040 %--- gradient K 385.8590 --- gradient x 16.7165
# iteration 2100 %--- gradient K 386.3951 --- gradient x 16.6552
# iteration 2160 %--- gradient K 387.0061 --- gradient x 16.5384
# iteration 2220 %--- gradient K 387.7599 --- gradient x 16.4722
# iteration 2280 %--- gradient K 388.4620 --- gradient x 16.5172
# iteration 2340 %--- gradient K 389.0639 --- gradient x 16.6435
# iteration 2400 %--- gradient K 389.9270 --- gradient x 16.7667
# iteration 2460 %--- gradient K 390.7576 --- gradient x 16.8350
# iteration 2520 %--- gradient K 391.4959 --- gradient x 16.8330
# iteration 2580 %--- gradient K 392.3241 --- gradient x 16.8103
# iteration 2640 %--- gradient K 393.3162 --- gradient x 16.8395
# iteration 2700 %--- gradient K 394.0494 --- gradient x 16.8958
# iteration 2760 %--- gradient K 394.9054 --- gradient x 16.9134
# iteration 2820 %--- gradient K 395.9669 --- gradient x 16.8815
# iteration 2880 %--- gradient K 396.7360 --- gradient x 16.8258
# iteration 2940 %--- gradient K 397.6503 --- gradient x 16.7756
# Final energy : 248.3799003115254

# %%
Export_ep(Ep22,label='2',cas='2')

# %%
Display_ker(K_out,K_in,mysize=(8,4))
Display_im(x_out,x_im,mysize=(6,3))
Display_epd(Ep22,Ed22)
# Out:
# Erreur |K1 - K2|/ |K2| : 0.9497
# Erreur |im1 - im2|/|im2| :0.5687

# %%
from Codes.simplex import Simplex
plt.plot(K_shift[20,:],label='shift')
plt.plot(K_out[20,:],label='out')
plt.plot(K[20,:],label='true')
plt.legend()

# %% [markdown]
# ## Initialisation noyau proche - bruit std 0.05
# Les erreurs initiales sont
#
# $$
# \begin{cases}
# e_K=0.2811 \\
# e_x=0.2724
# \end{cases}
# $$

# %%
alpha     = 100
mu        = 0.001
K_in      = K_shift.copy()
x_in      = x_o1
K_out,x_out,Ep23,Ed23 = violetBD(K_in,x_in,x_o1,\
                            alpha,mu,\
                            niter=3000,\
                            proj_simplex=True)

# %%
Export_ep(Ep23,label='2',cas='3')

# %%
Display_ker(K_out,K_in,mysize=(8,4))
Display_im(x_out,x_im,mysize=(6,3))
Display_epd(Ep23,Ed23)

# %%
from Codes.simplex import Simplex
plt.plot(K_shift[15,:],label='shift')
plt.plot(K_out[15,:],label='out')
plt.plot(K[15,:],label='true')
plt.legend()

# %% [markdown]
# ### ANNEXES

# %%
sys.exit()

# %%
Nx,Ny = x_im.shape
# Kernel padding
K_pad = np.zeros(x_im.shape)
K_pad[Nx//2-M:Nx//2+M,Ny//2-M:Ny//2+M] = K
# Derivation padding
d      = -np.ones((3,3))
d[1,1] = 8
d_pad  = np.zeros((Nx,Ny))
d_pad[Nx//2-1:Nx//2+2,Ny//2-1:Ny//2+2] = d
# Parameters
alpha = 0
mu    = 0
gamma = 1
#
conv1 = convolve(K_pad,x_im)
conv2 = convolve(d_pad,K_pad)
ux,uy = nablah(x_im)
normu = np.abs(ux)+np.abs(uy)
#
Ep_b  = 0.5*gamma*np.linalg.norm(conv1-x_b)**2 \
          + 0.5*alpha*np.linalg.norm(conv2)**2\
          + mu/Nx/Ny*np.sum(normu)
Ep_o1  = 0.5*gamma*np.linalg.norm(conv1-x_o1)**2 \
          + 0.5*alpha*np.linalg.norm(conv2)**2\
          + mu/Nx/Ny*np.sum(normu)
print(" Min functionnal blurred : {:.6f},\
     \n Min functionnal noise   : {:.6f}".format(Ep_b,Ep_o1))
