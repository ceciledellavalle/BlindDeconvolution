# %%
# General import
import numpy as np
from numpy.fft import fft2, ifft2, fftshift
import os
from PIL import Image
from scipy import signal
from scipy import interpolate
import matplotlib.pyplot as plt
# %matplotlib inline
# Local import
from Codes.dataprocess import DataGen
from Codes.dataprocess import Export_ep
from Codes.dataprocess import Add_noise
from Codes.algoviolet import violetBD
from Codes.display import Display_ker
from Codes.display import Display_im
from Codes.display import Display_epd
from Codes.myfunc import nablah
from Codes.myfunc import convolve
from Codes.simplex import Simplex

# %% [markdown]
# # Minimisation fonction bi-convexe concave

# %% [markdown]
# On introduit le probleme d'optimisation biconvex-concave
# de déconvolution aveugle d'images
# avec l' a priori de noyau de convolution régulier,
#
# $$
# \underset{u \in U ,K \in \Sigma}{\text{min}} \; \underset{v}{\text{sup}} \;
# \frac{1}{2} \| g - K * u\|^2
# + \frac{1}{2} \alpha \| D K \|^2
# + \langle \nabla u , v \rangle
# + \chi_{B,\mu}(v)
# \; .
# $$
#
# L'espace $\Sigma$ correspond à l'ensemble des simplexes
# (ensemble des noyaux à coefficient positif dont la somme des coefficients vaut 1).
# Par extension on notera $\Sigma$ la fonction indicatrice de cet ensemble.
# L'espace $U$ correspond à l'hypercube $[0,1]^{N_x \times N_y}$, ou la boule unité pour la norme $L^\infty$.
# Sa fonction indicatrice correspond donc à $\chi_{B,1}$.
#
# La fonction à minimiser peut alors se réécrire
#
# $$
# \underset{u ,K }{\text{min}} \; \underset{v}{\text{sup}} \;
# \frac{1}{2} \| g - K * u\|^2
# + \chi_{B,1} (u)
# + \frac{1}{2} \alpha \| D K \|^2
# + \Sigma(K)
# +\langle \nabla u , v \rangle
# + \chi_{B,\mu}(v)
# \; .
# $$

# %% [markdown]
# On note
#
# $$
# L =\frac{1}{2} \| g - K * u\|^2
# + \frac{1}{2} \alpha \| D K \|^2
# + \langle \nabla u , v \rangle
# $$

# %% [markdown]
# Pour résoudre ce probleme d'optimisation on se propose de tester l'algorithme suivant,
#
# $$
# \left\{
# \begin{align}
# & \tilde{u}_{k+1} = \text{proj}_{B_1} \; (u_k - \tau \partial_u L(u_k,K_k,v_k) \; )\\
# & K_{k+1} = \text{prox}_{\Sigma} \; (K_k - \gamma \partial_K L(\tilde{u}_{k+1},K_k,v_k) \; )\\
# & v_{k+1}         = \text{prox}_{B_\mu} \; (v_k + \sigma \partial_v L (u_{k+1},K_{k+1},v_k) \; )\\
# & u_{k+1} = \tilde{u}_{k+1} + \theta_u (\tilde{u}_{k+1} - u_k) \quad \text{(relaxation)}
# \end{align}
# \right.
# $$
#
# Question :
# est-ce qu'on met une relaxation aussi sur $K$ ?
#
# $$
# K_{k+1} = \tilde{K}_{k+1} + \theta_K (\tilde{K}_{k+1} - K_k)  \quad \text{(relaxation aussi ?)}
# $$
#
# On écrit alors les dérivées partielles de $L$,
#
# $$
# \left\{
# \begin{align}
# & \partial_u L(u_k,K_k,v_k) \; ) = \text{div} \cdot v_k - \tilde{K} * (g-K*u)\\
# & \partial_K L(\tilde{u}_{k+1},K_k,v_k) \; ) = - (g-K*u)*\tilde{u} + \alpha D^TDK \\
# & \partial_v L (u_{k+1},K_{k+1},v_k) \; ) =  \nabla u
# \end{align}
# \right.
# $$
#
# On trace les énergies primales et duales au cours de la minimisation
#
# $$
# \left\{
# \begin{align}
# & Ep = \frac{1}{2} \| g - K * u\|^2
# + \frac{1}{2} \alpha \| D K \|^2
# + \mu. \text{TV} (u) \\
# \\
# & Ed = - \langle \nabla u ,v \rangle - \chi_{B,\mu}(v)
# \end{align}
# \right.
# $$

# %%
K, K_shift, x_im, x_b, x_o1 = DataGen()
# Out:
# Erreur |K1 - K2|/ |K2| : 0.3500
# Erreur blurred |x_blurr- x_true|_2 :0.6436
# Erreur |x_noisy - x_true|_2 :0.6448

# %% [markdown]
# ## Initialisation du noyau exacte - bruit std 0.05
#
# Les erreurs initiales sont
#
# $$
# \begin{cases}
# e_K = 0 \\
# e_x = 0.2577
# \end{cases}
# $$

# %%
alpha = 1
mu    = 5
gamma = 1
K_in   = K.copy()
x_in  = x_o1
# K_out,x_out,Ep,Ed = violetBD(K_in,x_in,x_b,\
#                             alpha,mu,gamma,theta=1,\
#                             niter=10000,coeffK=0.1)

# %%
#Display_ker(K_out,K_in,mysize=(8,4))

# %%
#Display_im(x_out,x_im,mysize=(10,5))

# %%
#Display_epd(Ep,Ed)

# %% [markdown]
# ## Initialisation noyau proche - pas de bruit

# %%
alpha     = 1
mu        = 5
gamma     = 1
K_in      = K_shift.copy()
x_in      = x_b
# K_out,x_out,Ep,Ed = violetBD(K_in,x_in,x_b,\
#                             alpha,mu,gamma,theta=1,\
#                             niter=25000,coeffK=5,coeffx=2,\
#                             proj_simplex=False)
# Out:
# iteration 100 %--- gradient K 417.1962 --- gradient x 0.2878
# iteration 200 %--- gradient K 230.3736 --- gradient x 0.1509
# iteration 300 %--- gradient K 163.1792 --- gradient x 0.0935
# iteration 400 %--- gradient K 143.8455 --- gradient x 0.0713
# iteration 500 %--- gradient K 133.1163 --- gradient x 0.0586
# iteration 600 %--- gradient K 129.5068 --- gradient x 0.0507
# iteration 700 %--- gradient K 130.1286 --- gradient x 0.0466
# iteration 800 %--- gradient K 132.3969 --- gradient x 0.0451
# iteration 900 %--- gradient K 134.8456 --- gradient x 0.0450
# iteration 1000 %--- gradient K 137.6563 --- gradient x 0.0456
# iteration 1100 %--- gradient K 140.7322 --- gradient x 0.0467
# iteration 1200 %--- gradient K 143.7799 --- gradient x 0.0485
# iteration 1300 %--- gradient K 146.6257 --- gradient x 0.0505
# iteration 1400 %--- gradient K 149.8733 --- gradient x 0.0528
# iteration 1500 %--- gradient K 153.2099 --- gradient x 0.0550
# iteration 1600 %--- gradient K 156.5380 --- gradient x 0.0571
# iteration 1700 %--- gradient K 160.3432 --- gradient x 0.0593
# iteration 1800 %--- gradient K 164.2455 --- gradient x 0.0615
# iteration 1900 %--- gradient K 167.6259 --- gradient x 0.0632
# iteration 2000 %--- gradient K 170.8901 --- gradient x 0.0649
# iteration 2100 %--- gradient K 173.9336 --- gradient x 0.0666
# iteration 2200 %--- gradient K 176.3903 --- gradient x 0.0681
# iteration 2300 %--- gradient K 178.5495 --- gradient x 0.0696
# iteration 2400 %--- gradient K 180.4985 --- gradient x 0.0710
# iteration 2500 %--- gradient K 181.9699 --- gradient x 0.0723
# iteration 2600 %--- gradient K 183.2116 --- gradient x 0.0735
# iteration 2700 %--- gradient K 184.2973 --- gradient x 0.0747
# iteration 2800 %--- gradient K 184.9675 --- gradient x 0.0757
# iteration 2900 %--- gradient K 185.6041 --- gradient x 0.0766
# iteration 3000 %--- gradient K 185.7643 --- gradient x 0.0773
# iteration 3100 %--- gradient K 186.1049 --- gradient x 0.0779
# iteration 3200 %--- gradient K 185.9843 --- gradient x 0.0782
# iteration 3300 %--- gradient K 185.5925 --- gradient x 0.0782
# iteration 3400 %--- gradient K 185.1597 --- gradient x 0.0782
# iteration 3500 %--- gradient K 184.6211 --- gradient x 0.0781
# iteration 3600 %--- gradient K 184.2410 --- gradient x 0.0781
# iteration 3700 %--- gradient K 183.4479 --- gradient x 0.0776
# iteration 3800 %--- gradient K 182.8394 --- gradient x 0.0774
# iteration 3900 %--- gradient K 182.0832 --- gradient x 0.0770
# iteration 4000 %--- gradient K 181.3426 --- gradient x 0.0765
# iteration 4100 %--- gradient K 180.3792 --- gradient x 0.0758
# iteration 4200 %--- gradient K 179.4663 --- gradient x 0.0751
# iteration 4300 %--- gradient K 178.6403 --- gradient x 0.0745
# iteration 4400 %--- gradient K 177.6130 --- gradient x 0.0736
# iteration 4500 %--- gradient K 176.5308 --- gradient x 0.0728
# iteration 4600 %--- gradient K 175.8352 --- gradient x 0.0723
# iteration 4700 %--- gradient K 174.8815 --- gradient x 0.0715
# iteration 4800 %--- gradient K 173.9656 --- gradient x 0.0708
# iteration 4900 %--- gradient K 172.9811 --- gradient x 0.0700
# iteration 5000 %--- gradient K 172.2608 --- gradient x 0.0693
# iteration 5100 %--- gradient K 171.3815 --- gradient x 0.0687
# iteration 5200 %--- gradient K 170.5603 --- gradient x 0.0680
# iteration 5300 %--- gradient K 169.6759 --- gradient x 0.0673
# iteration 5400 %--- gradient K 168.8692 --- gradient x 0.0667
# iteration 5500 %--- gradient K 168.2855 --- gradient x 0.0663
# iteration 5600 %--- gradient K 167.5909 --- gradient x 0.0658
# iteration 5700 %--- gradient K 167.1852 --- gradient x 0.0655
# iteration 5800 %--- gradient K 166.6711 --- gradient x 0.0651
# iteration 5900 %--- gradient K 166.1383 --- gradient x 0.0648
# iteration 6000 %--- gradient K 165.6769 --- gradient x 0.0645
# iteration 6100 %--- gradient K 165.1954 --- gradient x 0.0641
# iteration 6200 %--- gradient K 164.6887 --- gradient x 0.0637
# iteration 6300 %--- gradient K 164.3894 --- gradient x 0.0635
# iteration 6400 %--- gradient K 164.1880 --- gradient x 0.0635
# iteration 6500 %--- gradient K 163.9361 --- gradient x 0.0633
# iteration 6600 %--- gradient K 163.7712 --- gradient x 0.0632
# iteration 6700 %--- gradient K 163.7572 --- gradient x 0.0633
# iteration 6800 %--- gradient K 163.6473 --- gradient x 0.0632
# iteration 6900 %--- gradient K 163.5626 --- gradient x 0.0632
# iteration 7000 %--- gradient K 163.6751 --- gradient x 0.0633
# iteration 7100 %--- gradient K 163.7406 --- gradient x 0.0633
# iteration 7200 %--- gradient K 163.7338 --- gradient x 0.0633
# iteration 7300 %--- gradient K 163.8055 --- gradient x 0.0634
# iteration 7400 %--- gradient K 164.0396 --- gradient x 0.0637
# iteration 7500 %--- gradient K 164.2288 --- gradient x 0.0639
# iteration 7600 %--- gradient K 164.3719 --- gradient x 0.0640
# iteration 7700 %--- gradient K 164.4753 --- gradient x 0.0641
# iteration 7800 %--- gradient K 164.7378 --- gradient x 0.0643
# iteration 7900 %--- gradient K 165.0018 --- gradient x 0.0646
# iteration 8000 %--- gradient K 165.1946 --- gradient x 0.0647
# iteration 8100 %--- gradient K 165.3945 --- gradient x 0.0648
# iteration 8200 %--- gradient K 165.6699 --- gradient x 0.0649
# iteration 8300 %--- gradient K 166.1322 --- gradient x 0.0653
# iteration 8400 %--- gradient K 166.5370 --- gradient x 0.0655
# iteration 8500 %--- gradient K 166.9045 --- gradient x 0.0657
# iteration 8600 %--- gradient K 167.2777 --- gradient x 0.0658
# iteration 8700 %--- gradient K 167.7538 --- gradient x 0.0661
# iteration 8800 %--- gradient K 168.3573 --- gradient x 0.0665
# iteration 8900 %--- gradient K 168.8999 --- gradient x 0.0669
# iteration 9000 %--- gradient K 169.4582 --- gradient x 0.0673
# iteration 9100 %--- gradient K 169.9511 --- gradient x 0.0675
# iteration 9200 %--- gradient K 170.4495 --- gradient x 0.0678
# iteration 9300 %--- gradient K 170.9633 --- gradient x 0.0681
# iteration 9400 %--- gradient K 171.5109 --- gradient x 0.0685
# iteration 9500 %--- gradient K 172.0525 --- gradient x 0.0688
# iteration 9600 %--- gradient K 172.5027 --- gradient x 0.0691
# iteration 9700 %--- gradient K 172.9535 --- gradient x 0.0693
# iteration 9800 %--- gradient K 173.3584 --- gradient x 0.0695
# iteration 9900 %--- gradient K 173.7802 --- gradient x 0.0698
# iteration 10000 %--- gradient K 174.1635 --- gradient x 0.0700
# iteration 10100 %--- gradient K 174.6329 --- gradient x 0.0703
# iteration 10200 %--- gradient K 175.0670 --- gradient x 0.0706
# iteration 10300 %--- gradient K 175.4508 --- gradient x 0.0708
# iteration 10400 %--- gradient K 175.8096 --- gradient x 0.0710
# iteration 10500 %--- gradient K 176.1369 --- gradient x 0.0711
# iteration 10600 %--- gradient K 176.5300 --- gradient x 0.0713
# iteration 10700 %--- gradient K 176.9091 --- gradient x 0.0715
# iteration 10800 %--- gradient K 177.3605 --- gradient x 0.0718
# iteration 10900 %--- gradient K 177.7129 --- gradient x 0.0720
# iteration 11000 %--- gradient K 178.0935 --- gradient x 0.0722
# iteration 11100 %--- gradient K 178.4403 --- gradient x 0.0724
# iteration 11200 %--- gradient K 178.7629 --- gradient x 0.0726
# iteration 11300 %--- gradient K 179.1087 --- gradient x 0.0727
# iteration 11400 %--- gradient K 179.4187 --- gradient x 0.0729
# iteration 11500 %--- gradient K 179.7892 --- gradient x 0.0731
# iteration 11600 %--- gradient K 180.1993 --- gradient x 0.0733
# iteration 11700 %--- gradient K 180.5857 --- gradient x 0.0736
# iteration 11800 %--- gradient K 180.9325 --- gradient x 0.0737
# iteration 11900 %--- gradient K 181.2582 --- gradient x 0.0739
# iteration 12000 %--- gradient K 181.6176 --- gradient x 0.0741
# iteration 12100 %--- gradient K 181.9607 --- gradient x 0.0742
# iteration 12200 %--- gradient K 182.2642 --- gradient x 0.0743
# iteration 12300 %--- gradient K 182.6062 --- gradient x 0.0745
# iteration 12400 %--- gradient K 182.9483 --- gradient x 0.0747
# iteration 12500 %--- gradient K 183.3212 --- gradient x 0.0749
# iteration 12600 %--- gradient K 183.7506 --- gradient x 0.0752
# iteration 12700 %--- gradient K 184.1093 --- gradient x 0.0754
# iteration 12800 %--- gradient K 184.4553 --- gradient x 0.0755
# iteration 12900 %--- gradient K 184.8089 --- gradient x 0.0757
# iteration 13000 %--- gradient K 185.1403 --- gradient x 0.0758
# iteration 13100 %--- gradient K 185.4840 --- gradient x 0.0760
# iteration 13200 %--- gradient K 185.8733 --- gradient x 0.0762
# iteration 13300 %--- gradient K 186.2292 --- gradient x 0.0764
# iteration 13400 %--- gradient K 186.6023 --- gradient x 0.0766
# iteration 13500 %--- gradient K 186.9893 --- gradient x 0.0768
# iteration 13600 %--- gradient K 187.3874 --- gradient x 0.0770
# iteration 13700 %--- gradient K 187.7811 --- gradient x 0.0772
# iteration 13800 %--- gradient K 188.1108 --- gradient x 0.0774
# iteration 13900 %--- gradient K 188.4355 --- gradient x 0.0776
# iteration 14000 %--- gradient K 188.7527 --- gradient x 0.0778
# iteration 14100 %--- gradient K 189.0535 --- gradient x 0.0779
# iteration 14200 %--- gradient K 189.3419 --- gradient x 0.0781
# iteration 14300 %--- gradient K 189.6253 --- gradient x 0.0782
# iteration 14400 %--- gradient K 189.9120 --- gradient x 0.0783
# iteration 14500 %--- gradient K 190.2469 --- gradient x 0.0785
# iteration 14600 %--- gradient K 190.5555 --- gradient x 0.0787
# iteration 14700 %--- gradient K 190.8467 --- gradient x 0.0788
# iteration 14800 %--- gradient K 191.1027 --- gradient x 0.0789
# iteration 14900 %--- gradient K 191.4005 --- gradient x 0.0791
# iteration 15000 %--- gradient K 191.6833 --- gradient x 0.0792
# iteration 15100 %--- gradient K 191.9671 --- gradient x 0.0794
# iteration 15200 %--- gradient K 192.2123 --- gradient x 0.0795
# iteration 15300 %--- gradient K 192.4416 --- gradient x 0.0796
# iteration 15400 %--- gradient K 192.6533 --- gradient x 0.0797
# iteration 15500 %--- gradient K 192.8345 --- gradient x 0.0798
# iteration 15600 %--- gradient K 193.0245 --- gradient x 0.0798
# iteration 15700 %--- gradient K 193.2086 --- gradient x 0.0799
# iteration 15800 %--- gradient K 193.3697 --- gradient x 0.0799
# iteration 15900 %--- gradient K 193.5281 --- gradient x 0.0799
# iteration 16000 %--- gradient K 193.6821 --- gradient x 0.0800
# iteration 16100 %--- gradient K 193.8455 --- gradient x 0.0800
# iteration 16200 %--- gradient K 194.0171 --- gradient x 0.0801
# iteration 16300 %--- gradient K 194.2089 --- gradient x 0.0801
# iteration 16400 %--- gradient K 194.4135 --- gradient x 0.0802
# iteration 16500 %--- gradient K 194.6289 --- gradient x 0.0803
# iteration 16600 %--- gradient K 194.8523 --- gradient x 0.0804
# iteration 16700 %--- gradient K 195.1039 --- gradient x 0.0806
# iteration 16800 %--- gradient K 195.3088 --- gradient x 0.0807
# iteration 16900 %--- gradient K 195.4985 --- gradient x 0.0808
# iteration 17000 %--- gradient K 195.6656 --- gradient x 0.0808
# iteration 17100 %--- gradient K 195.8337 --- gradient x 0.0809
# iteration 17200 %--- gradient K 195.9957 --- gradient x 0.0809
# iteration 17300 %--- gradient K 196.1540 --- gradient x 0.0810
# iteration 17400 %--- gradient K 196.3075 --- gradient x 0.0810
# iteration 17500 %--- gradient K 196.4602 --- gradient x 0.0811
# iteration 17600 %--- gradient K 196.6032 --- gradient x 0.0811
# iteration 17700 %--- gradient K 196.7414 --- gradient x 0.0811
# iteration 17800 %--- gradient K 196.8824 --- gradient x 0.0812
# iteration 17900 %--- gradient K 197.0411 --- gradient x 0.0812
# iteration 18000 %--- gradient K 197.1710 --- gradient x 0.0812
# iteration 18100 %--- gradient K 197.3049 --- gradient x 0.0812
# iteration 18200 %--- gradient K 197.4431 --- gradient x 0.0813
# iteration 18300 %--- gradient K 197.5728 --- gradient x 0.0813
# iteration 18400 %--- gradient K 197.7143 --- gradient x 0.0813
# iteration 18500 %--- gradient K 197.9015 --- gradient x 0.0814
# iteration 18600 %--- gradient K 198.0713 --- gradient x 0.0815
# iteration 18700 %--- gradient K 198.2913 --- gradient x 0.0816
# iteration 18800 %--- gradient K 198.4737 --- gradient x 0.0817
# iteration 18900 %--- gradient K 198.6749 --- gradient x 0.0819
# iteration 19000 %--- gradient K 198.8561 --- gradient x 0.0820
# iteration 19100 %--- gradient K 199.0230 --- gradient x 0.0820
# iteration 19200 %--- gradient K 199.1871 --- gradient x 0.0821
# iteration 19300 %--- gradient K 199.3290 --- gradient x 0.0822
# iteration 19400 %--- gradient K 199.4673 --- gradient x 0.0822
# iteration 19500 %--- gradient K 199.6049 --- gradient x 0.0823
# iteration 19600 %--- gradient K 199.7415 --- gradient x 0.0823
# iteration 19700 %--- gradient K 199.8738 --- gradient x 0.0823
# iteration 19800 %--- gradient K 200.0035 --- gradient x 0.0824
# iteration 19900 %--- gradient K 200.1419 --- gradient x 0.0824
# iteration 20000 %--- gradient K 200.2714 --- gradient x 0.0825
# iteration 20100 %--- gradient K 200.3931 --- gradient x 0.0825
# iteration 20200 %--- gradient K 200.5170 --- gradient x 0.0825
# iteration 20300 %--- gradient K 200.6445 --- gradient x 0.0826
# iteration 20400 %--- gradient K 200.7729 --- gradient x 0.0826
# iteration 20500 %--- gradient K 200.9024 --- gradient x 0.0827
# iteration 20600 %--- gradient K 201.0240 --- gradient x 0.0827
# iteration 20700 %--- gradient K 201.1459 --- gradient x 0.0827
# iteration 20800 %--- gradient K 201.2668 --- gradient x 0.0828
# iteration 20900 %--- gradient K 201.3864 --- gradient x 0.0828
# iteration 21000 %--- gradient K 201.5012 --- gradient x 0.0828
# iteration 21100 %--- gradient K 201.6077 --- gradient x 0.0828
# iteration 21200 %--- gradient K 201.7153 --- gradient x 0.0829
# iteration 21300 %--- gradient K 201.8490 --- gradient x 0.0829
# iteration 21400 %--- gradient K 202.0139 --- gradient x 0.0830
# iteration 21500 %--- gradient K 202.1698 --- gradient x 0.0831
# iteration 21600 %--- gradient K 202.3089 --- gradient x 0.0832
# iteration 21700 %--- gradient K 202.4407 --- gradient x 0.0833
# iteration 21800 %--- gradient K 202.5678 --- gradient x 0.0833
# iteration 21900 %--- gradient K 202.6921 --- gradient x 0.0834
# iteration 22000 %--- gradient K 202.8125 --- gradient x 0.0835
# iteration 22100 %--- gradient K 202.9384 --- gradient x 0.0835
# iteration 22200 %--- gradient K 203.0734 --- gradient x 0.0836
# iteration 22300 %--- gradient K 203.1855 --- gradient x 0.0836
# iteration 22400 %--- gradient K 203.2989 --- gradient x 0.0837
# iteration 22500 %--- gradient K 203.4051 --- gradient x 0.0837
# iteration 22600 %--- gradient K 203.5099 --- gradient x 0.0837
# iteration 22700 %--- gradient K 203.6118 --- gradient x 0.0838
# iteration 22800 %--- gradient K 203.7113 --- gradient x 0.0838
# iteration 22900 %--- gradient K 203.8115 --- gradient x 0.0838
# iteration 23000 %--- gradient K 203.9129 --- gradient x 0.0839
# iteration 23100 %--- gradient K 204.0116 --- gradient x 0.0839
# iteration 23200 %--- gradient K 204.1021 --- gradient x 0.0839
# iteration 23300 %--- gradient K 204.1940 --- gradient x 0.0840
# iteration 23400 %--- gradient K 204.2832 --- gradient x 0.0840
# iteration 23500 %--- gradient K 204.3689 --- gradient x 0.0840
# iteration 23600 %--- gradient K 204.4503 --- gradient x 0.0840
# iteration 23700 %--- gradient K 204.5417 --- gradient x 0.0840
# iteration 23800 %--- gradient K 204.6216 --- gradient x 0.0841
# iteration 23900 %--- gradient K 204.6969 --- gradient x 0.0841
# iteration 24000 %--- gradient K 204.7642 --- gradient x 0.0841
# iteration 24100 %--- gradient K 204.8374 --- gradient x 0.0841
# iteration 24200 %--- gradient K 204.9099 --- gradient x 0.0841
# iteration 24300 %--- gradient K 204.9862 --- gradient x 0.0841
# iteration 24400 %--- gradient K 205.0584 --- gradient x 0.0841
# iteration 24500 %--- gradient K 205.1295 --- gradient x 0.0842
# iteration 24600 %--- gradient K 205.2005 --- gradient x 0.0842
# iteration 24700 %--- gradient K 205.2809 --- gradient x 0.0842
# iteration 24800 %--- gradient K 205.3667 --- gradient x 0.0842
# iteration 24900 %--- gradient K 205.4479 --- gradient x 0.0843

# %%
# Display_ker(K_out,K_in,mysize=(8,4))
# Display_im(x_out,x_im,mysize=(10,5))
# Out:
# Erreur |K1 - K2|/ |K2| : 0.4890
# Erreur |im1 - im2|/|im2| :0.6048

# %%
# # local parameters and matrix sizes
# M,_    = K.shape
# M      = M//2 # kernel middle size
# Nx, Ny = x_b.shape # image size
# # kernel position (for padding)
# min_x  = Nx//2+1-M-2
# max_x  = Nx//2+M-1
# min_y  = Ny//2+1-M-2
# max_y  = Ny//2+M-1
# # Initialisation
# Kk                          = np.zeros((Nx,Ny))
# Kk[min_x:max_x,min_y:max_y] = K_out
# Display_im(convolve(x_out,Kk)-x_o1,x_o1,mysize=(10,5))
# Out:
# Erreur |im1 - im2|/|im2| :1.0035

# %%
# np.amax(convolve(x_out,Kk)-x_o1)/np.amax(x_o1)
# Out:
# 0.08093099630116757

# %%
Export_ep(Ep,label='2')

# %% [markdown]
# ## Initialisation noyau proche - bruit std 0.05
# Les erreurs initiales sont
#
# $$
# \begin{cases}
# e_K=0.2811 \\
# e_x=0.2724
# \end{cases}
# $$

# %%
alpha = 1
mu    = 5
gamma = 1
K_in      = K_shift.copy()
x_in      = x_o1
K_out,x_out,Ep,Ed = violetBD(K_in,x_in,x_o1,\
                            alpha,mu,gamma,theta=1,\
                            niter=25000,coeffK=5,coeffx=1,\
                            proj_simplex=False)
# Out:
# iteration 100 %--- gradient K 548.6499 --- gradient x 0.4410
# iteration 200 %--- gradient K 301.2601 --- gradient x 0.2178
# iteration 300 %--- gradient K 231.6876 --- gradient x 0.1472
# iteration 400 %--- gradient K 204.0979 --- gradient x 0.1083
# iteration 500 %--- gradient K 188.6977 --- gradient x 0.0879
# iteration 600 %--- gradient K 179.6841 --- gradient x 0.0781
# iteration 700 %--- gradient K 174.2442 --- gradient x 0.0720
# iteration 800 %--- gradient K 171.4773 --- gradient x 0.0680
# iteration 900 %--- gradient K 170.1725 --- gradient x 0.0646
# iteration 1000 %--- gradient K 169.0980 --- gradient x 0.0625
# iteration 1100 %--- gradient K 168.4827 --- gradient x 0.0608
# iteration 1200 %--- gradient K 168.2909 --- gradient x 0.0596

# %%
Display_ker(K_out,K,mysize=(8,4))
Display_im(x_out,x_im,mysize=(10,5))

# %%
Export_ep(Ep,label='2',cas='3')

# %% [markdown]
# ### ANNEXES

# %%
Nx,Ny = x_i.shape
# Kernel padding
K_pad = np.zeros(x_i.shape)
K_pad[Nx//2+1-M-2:Nx//2+M-1,Ny//2+1-M-2:Ny//2+M-1] = K
# Derivation padding
d      = -np.ones((3,3))
d[1,1] = 8
d_pad  = np.zeros((Nx,Ny))
d_pad[Nx//2-1:Nx//2+2,Ny//2-1:Ny//2+2] = d
# Parameters
alpha = 1*80**2
mu    = 1
gamma = 1
#
conv1 = convolve(K_pad,x_i)
conv2 = convolve(d_pad,K_pad)
ux,uy = nablah(x_i)
normu = np.abs(ux)+np.abs(uy)
#
Ep_b  = 0.5*gamma*np.linalg.norm(conv1-x_b)**2 \
          + 0.5*alpha*np.linalg.norm(conv2)**2\
          + mu/Nx/Ny*np.sum(normu)
Ep_o1  = 0.5*gamma*np.linalg.norm(conv1-x_o1)**2 \
          + 0.5*alpha*np.linalg.norm(conv2)**2\
          + mu/Nx/Ny*np.sum(normu)
print(" Min functionnal blurred : {:.6f},\
     \n Min functionnal noise   : {:.6f}".format(Ep_b,Ep_o1))
