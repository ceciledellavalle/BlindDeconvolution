# %%
# General import
import numpy as np
from numpy.fft import fft2, ifft2, fftshift
import matplotlib.pyplot as plt
# %matplotlib inline
# Local import
from Codes.dataprocess import DataGen
from Codes.dataprocess import Export_ep
from Codes.dataprocess import Add_noise
from Codes.algoviolet import violetBD
from Codes.display import Display_ker
from Codes.display import Display_im
from Codes.display import Display_epd
from Codes.myfunc import nablah
from Codes.myfunc import convolve
from Codes.simplex import Simplex

# %% [markdown]
# # Minimisation fonction bi-convexe concave

# %% [markdown]
# On introduit le probleme d'optimisation biconvex-concave
# de déconvolution aveugle d'images
# avec l' a priori de noyau de convolution régulier,
#
# $$
# \underset{u \in U ,K \in \Sigma}{\text{min}} \; \underset{v}{\text{sup}} \;
# \frac{1}{2} \| g - K * u\|^2
# + \frac{1}{2} \alpha \| D K \|^2
# + \langle \nabla u , v \rangle
# + \chi_{B,\mu}(v)
# \; .
# $$
#
# L'espace $\Sigma$ correspond à l'ensemble des simplexes
# (ensemble des noyaux à coefficient positif dont la somme des coefficients vaut 1).
# Par extension on notera $\Sigma$ la fonction indicatrice de cet ensemble.
# L'espace $U$ correspond à l'hypercube $[0,1]^{N_x \times N_y}$, ou la boule unité pour la norme $L^\infty$.
# Sa fonction indicatrice correspond donc à $\chi_{B,1}$.
#
# La fonction à minimiser peut alors se réécrire
#
# $$
# \underset{u ,K }{\text{min}} \; \underset{v}{\text{sup}} \;
# \frac{1}{2} \| g - K * u\|^2
# + \chi_{B,1} (u)
# + \frac{1}{2} \alpha \| D K \|^2
# + \Sigma(K)
# +\langle \nabla u , v \rangle
# + \chi_{B,\mu}(v)
# \; .
# $$

# %% [markdown]
# On note
#
# $$
# L =\frac{1}{2} \| g - K * u\|^2
# + \frac{1}{2} \alpha \| D K \|^2
# + \langle \nabla u , v \rangle
# $$

# %% [markdown]
# Pour résoudre ce probleme d'optimisation on se propose de tester l'algorithme suivant,
#
# $$
# \left\{
# \begin{align}
# & \tilde{u}_{k+1} = \text{proj}_{B_1} \; (u_k - \tau \partial_u L(u_k,K_k,v_k) \; )\\
# & K_{k+1} = \text{prox}_{\Sigma} \; (K_k - \gamma \partial_K L(\tilde{u}_{k+1},K_k,v_k) \; )\\
# & v_{k+1}         = \text{prox}_{B_\mu} \; (v_k + \sigma \partial_v L (u_{k+1},K_{k+1},v_k) \; )\\
# & u_{k+1} = \tilde{u}_{k+1} + \theta_u (\tilde{u}_{k+1} - u_k) \quad \text{(relaxation)}
# \end{align}
# \right.
# $$
#
# Question :
# est-ce qu'on met une relaxation aussi sur $K$ ?
#
# $$
# K_{k+1} = \tilde{K}_{k+1} + \theta_K (\tilde{K}_{k+1} - K_k)  \quad \text{(relaxation aussi ?)}
# $$
#
# On écrit alors les dérivées partielles de $L$,
#
# $$
# \left\{
# \begin{align}
# & \partial_u L(u_k,K_k,v_k) \; ) = \text{div} \cdot v_k - \tilde{K} * (g-K*u)\\
# & \partial_K L(\tilde{u}_{k+1},K_k,v_k) \; ) = - (g-K*u)*\tilde{u} + \alpha D^TDK \\
# & \partial_v L (u_{k+1},K_{k+1},v_k) \; ) =  \nabla u
# \end{align}
# \right.
# $$
#
# On trace les énergies primales et duales au cours de la minimisation
#
# $$
# \left\{
# \begin{align}
# & Ep = \frac{1}{2} \| g - K * u\|^2
# + \frac{1}{2} \alpha \| D K \|^2
# + \mu. \text{TV} (u) \\
# \\
# & Ed = - \langle \nabla u ,v \rangle - \chi_{B,\mu}(v)
# \end{align}
# \right.
# $$

# %%
K, K_shift, x_im, x_b, x_o1 = DataGen()
# Out:
# Erreur |K1 - K2|/ |K2| : 0.3500
# Erreur blurred |x_blurr- x_true|_2 :0.6363
# Erreur |x_noisy - x_true|_2 :0.6372

# %% [markdown]
# ## Initialisation du noyau exacte - bruit std 0.05
#
# Les erreurs initiales sont
#
# $$
# \begin{cases}
# e_K = 0 \\
# e_x = 0.2577
# \end{cases}
# $$

# %%
alpha = 100
mu    = 0.001
K_in   = K.copy()
x_in  = x_o1
K_out,x_out,Ep21,Ed21 = violetBD(K_in,x_in,x_b,alpha,mu,\
                            niter=10000,coeffK=0.01,\
                            proj_simplex=True)
# Out:
# iteration 1 %--- gradient K 927.0622 --- gradient x 2.2584
# iteration 2 %--- gradient K 867.5858 --- gradient x 2.4087
# iteration 3 %--- gradient K 814.4417 --- gradient x 2.4697
# iteration 4 %--- gradient K 771.9719 --- gradient x 2.4460
# iteration 5 %--- gradient K 745.6891 --- gradient x 2.3594
# iteration 6 %--- gradient K 743.9848 --- gradient x 2.2208
# iteration 7 %--- gradient K 761.8785 --- gradient x 2.0402
# iteration 8 %--- gradient K 787.4641 --- gradient x 1.8407
# iteration 9 %--- gradient K 812.3932 --- gradient x 1.6568
# iteration 10 %--- gradient K 833.1220 --- gradient x 1.5279
# iteration 11 %--- gradient K 847.3536 --- gradient x 1.4752
# iteration 12 %--- gradient K 854.3312 --- gradient x 1.4826
# iteration 13 %--- gradient K 854.5210 --- gradient x 1.5117
# iteration 14 %--- gradient K 849.3038 --- gradient x 1.5331
# iteration 15 %--- gradient K 839.7594 --- gradient x 1.5324
# iteration 16 %--- gradient K 828.0423 --- gradient x 1.5058
# iteration 17 %--- gradient K 817.6597 --- gradient x 1.4569
# iteration 18 %--- gradient K 809.1855 --- gradient x 1.3953
# iteration 19 %--- gradient K 801.8161 --- gradient x 1.3342
# iteration 20 %--- gradient K 793.8930 --- gradient x 1.2860
# iteration 21 %--- gradient K 784.4292 --- gradient x 1.2575
# iteration 22 %--- gradient K 773.4620 --- gradient x 1.2463
# iteration 23 %--- gradient K 761.3267 --- gradient x 1.2432
# iteration 24 %--- gradient K 749.0369 --- gradient x 1.2385
# iteration 25 %--- gradient K 736.9694 --- gradient x 1.2260
# iteration 26 %--- gradient K 725.6289 --- gradient x 1.2017
# iteration 27 %--- gradient K 714.5108 --- gradient x 1.1654
# iteration 28 %--- gradient K 703.3404 --- gradient x 1.1219
# iteration 29 %--- gradient K 692.1211 --- gradient x 1.0812
# iteration 30 %--- gradient K 680.8970 --- gradient x 1.0541
# iteration 31 %--- gradient K 669.2427 --- gradient x 1.0451
# iteration 32 %--- gradient K 657.0645 --- gradient x 1.0524
# iteration 33 %--- gradient K 644.8953 --- gradient x 1.0678
# iteration 34 %--- gradient K 632.5850 --- gradient x 1.0817
# iteration 35 %--- gradient K 620.0431 --- gradient x 1.0856
# iteration 36 %--- gradient K 607.4963 --- gradient x 1.0752
# iteration 37 %--- gradient K 595.2459 --- gradient x 1.0506
# iteration 38 %--- gradient K 583.5231 --- gradient x 1.0151
# iteration 39 %--- gradient K 572.0464 --- gradient x 0.9749
# iteration 40 %--- gradient K 560.9034 --- gradient x 0.9389
# iteration 41 %--- gradient K 550.1080 --- gradient x 0.9169
# iteration 42 %--- gradient K 539.4029 --- gradient x 0.9133
# iteration 43 %--- gradient K 528.7704 --- gradient x 0.9263
# iteration 44 %--- gradient K 518.1682 --- gradient x 0.9465
# iteration 45 %--- gradient K 507.7094 --- gradient x 0.9654
# iteration 46 %--- gradient K 497.4432 --- gradient x 0.9753
# iteration 47 %--- gradient K 487.3644 --- gradient x 0.9716
# iteration 48 %--- gradient K 477.5115 --- gradient x 0.9547
# iteration 49 %--- gradient K 467.9501 --- gradient x 0.9280
# Final energy : 4.400725176847732

# %%
Display_ker(K_out,K_in,mysize=(8,4))
Display_im(x_out,x_im,mysize=(6,3))
Display_epd(Ep21,Ed21)
# Out:
# Erreur |K1 - K2|/ |K2| : 0.2095
# Erreur |im1 - im2|/|im2| :0.6027

# %%
Export_ep(Ep21,label='2',cas='1')

# %% [markdown]
# ## Initialisation noyau proche - pas de bruit

# %%
alpha     = 100
mu        = 0.001
K_in      = K_shift.copy()
x_in      = x_b
K_out,x_out,Ep22,Ed22 = violetBD(K_in,x_in,x_b,alpha,mu,\
                            niter=10000,\
                            proj_simplex=True)
# Out:
# iteration 1 %--- gradient K 1245.1120 --- gradient x 2.2250
# iteration 2 %--- gradient K 1249.6482 --- gradient x 2.1268
# iteration 3 %--- gradient K 1273.7306 --- gradient x 2.0407
# iteration 4 %--- gradient K 1311.1128 --- gradient x 1.9646
# iteration 5 %--- gradient K 1355.9314 --- gradient x 1.8967
# iteration 6 %--- gradient K 1404.4029 --- gradient x 1.8360
# iteration 7 %--- gradient K 1452.9490 --- gradient x 1.7813
# iteration 8 %--- gradient K 1499.7456 --- gradient x 1.7317
# iteration 9 %--- gradient K 1544.0507 --- gradient x 1.6867
# iteration 10 %--- gradient K 1584.6687 --- gradient x 1.6456
# iteration 11 %--- gradient K 1622.0506 --- gradient x 1.6080
# iteration 12 %--- gradient K 1655.6989 --- gradient x 1.5734
# iteration 13 %--- gradient K 1685.4694 --- gradient x 1.5415
# iteration 14 %--- gradient K 1711.9017 --- gradient x 1.5119
# iteration 15 %--- gradient K 1735.0480 --- gradient x 1.4844
# iteration 16 %--- gradient K 1754.9702 --- gradient x 1.4588
# iteration 17 %--- gradient K 1771.9961 --- gradient x 1.4349
# iteration 18 %--- gradient K 1786.0762 --- gradient x 1.4123
# iteration 19 %--- gradient K 1797.0968 --- gradient x 1.3910
# iteration 20 %--- gradient K 1805.9465 --- gradient x 1.3708
# iteration 21 %--- gradient K 1812.7182 --- gradient x 1.3517
# iteration 22 %--- gradient K 1817.9590 --- gradient x 1.3337
# iteration 23 %--- gradient K 1821.6688 --- gradient x 1.3166
# iteration 24 %--- gradient K 1824.0837 --- gradient x 1.3003
# iteration 25 %--- gradient K 1824.8746 --- gradient x 1.2848
# iteration 26 %--- gradient K 1824.3976 --- gradient x 1.2699
# iteration 27 %--- gradient K 1822.4377 --- gradient x 1.2556
# iteration 28 %--- gradient K 1819.5180 --- gradient x 1.2418
# iteration 29 %--- gradient K 1815.8717 --- gradient x 1.2286
# iteration 30 %--- gradient K 1811.4135 --- gradient x 1.2159
# iteration 31 %--- gradient K 1806.4468 --- gradient x 1.2037
# iteration 32 %--- gradient K 1800.9636 --- gradient x 1.1920
# iteration 33 %--- gradient K 1794.9478 --- gradient x 1.1806
# iteration 34 %--- gradient K 1788.6238 --- gradient x 1.1697
# iteration 35 %--- gradient K 1781.9941 --- gradient x 1.1591
# iteration 36 %--- gradient K 1775.0058 --- gradient x 1.1488
# iteration 37 %--- gradient K 1767.6755 --- gradient x 1.1389
# iteration 38 %--- gradient K 1760.1036 --- gradient x 1.1292
# iteration 39 %--- gradient K 1752.3510 --- gradient x 1.1198
# iteration 40 %--- gradient K 1744.4634 --- gradient x 1.1107
# iteration 41 %--- gradient K 1736.5538 --- gradient x 1.1019
# iteration 42 %--- gradient K 1728.3890 --- gradient x 1.0933
# iteration 43 %--- gradient K 1720.1481 --- gradient x 1.0849
# iteration 44 %--- gradient K 1711.9135 --- gradient x 1.0768
# iteration 45 %--- gradient K 1703.6162 --- gradient x 1.0689
# iteration 46 %--- gradient K 1695.1282 --- gradient x 1.0611
# iteration 47 %--- gradient K 1686.6087 --- gradient x 1.0535
# iteration 48 %--- gradient K 1678.1833 --- gradient x 1.0460
# iteration 49 %--- gradient K 1669.8005 --- gradient x 1.0388
# Final energy : 4.958579414520689

# %%
Export_ep(Ep22,label='2',cas='2')

# %%
Display_ker(K_out,K_in,mysize=(8,4))
Display_im(x_out,x_im,mysize=(6,3))
Display_epd(Ep22,Ed22)
# Out:
# Erreur |K1 - K2|/ |K2| : 0.2095
# Erreur |im1 - im2|/|im2| :0.6027

# %%
from Codes.simplex import Simplex
plt.plot(K_shift[40,:],label='shift')
plt.plot(K_out[40,:],label='out')
plt.plot(K[40,:],label='true')
plt.legend()

# %% [markdown]
# ## Initialisation noyau proche - bruit std 0.05
# Les erreurs initiales sont
#
# $$
# \begin{cases}
# e_K=0.2811 \\
# e_x=0.2724
# \end{cases}
# $$

# %%
alpha     = 100
mu        = 0.001
K_in      = K_shift.copy()
x_in      = x_o1
K_out,x_out,Ep23,Ed23 = violetBD(K_in,x_in,x_o1,\
                            alpha,mu,\
                            niter=10000,\
                            proj_simplex=True)

# %%
Export_ep(Ep23,label='2',cas='3')

# %%
Display_ker(K_out,K_in,mysize=(8,4))
Display_im(x_out,x_im,mysize=(6,3))
Display_epd(Ep23,Ed23)

# %%
from Codes.simplex import Simplex
plt.plot(K_shift[40,:],label='shift')
plt.plot(K_out[40,:],label='out')
plt.plot(K[40,:],label='true')
plt.legend()

# %% [markdown]
# ### ANNEXES

# %%
sys.exit()

# %%
Nx,Ny = x_im.shape
# Kernel padding
K_pad = np.zeros(x_im.shape)
K_pad[Nx//2-M:Nx//2+M,Ny//2-M:Ny//2+M] = K
# Derivation padding
d      = -np.ones((3,3))
d[1,1] = 8
d_pad  = np.zeros((Nx,Ny))
d_pad[Nx//2-1:Nx//2+2,Ny//2-1:Ny//2+2] = d
# Parameters
alpha = 0
mu    = 0
gamma = 1
#
conv1 = convolve(K_pad,x_im)
conv2 = convolve(d_pad,K_pad)
ux,uy = nablah(x_im)
normu = np.abs(ux)+np.abs(uy)
#
Ep_b  = 0.5*gamma*np.linalg.norm(conv1-x_b)**2 \
          + 0.5*alpha*np.linalg.norm(conv2)**2\
          + mu/Nx/Ny*np.sum(normu)
Ep_o1  = 0.5*gamma*np.linalg.norm(conv1-x_o1)**2 \
          + 0.5*alpha*np.linalg.norm(conv2)**2\
          + mu/Nx/Ny*np.sum(normu)
print(" Min functionnal blurred : {:.6f},\
     \n Min functionnal noise   : {:.6f}".format(Ep_b,Ep_o1))
